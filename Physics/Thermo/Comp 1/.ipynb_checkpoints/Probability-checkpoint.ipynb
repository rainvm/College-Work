# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(10, 200, 20)
dist = []
mean = []
stdev = []
for i in range (20):
    dist.append( np.random.normal(100, 10, (i+1)*10))
    mean.append(np.mean(dist[i]))
    stdev.append(np.std(dist[i]))
    
fig, (axMean, axStdev) = plt.subplots(2,1, figsize=(8,10))
fig.subplots_adjust(hspace=0.275)

axMean.plot(x, mean)
axMean.set_title("Mean vs N",fontsize=18)

axStdev.plot(x, stdev)
axStdev.set_title("Standard Deviation vs N",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Standard Deviation vs N')
