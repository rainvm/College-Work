# %%
import polars as po
import matplotlib.pyplot as plt

data = [po.read_csv("RLC Series Network.csv", skip_rows=12), 
        po.read_csv("RLC Parallel Network.csv", skip_rows=12)]
plt.plot(data[0][["time"]], data[0][["gain"]])
plt.xscale("log")
plt.grid(True)
plt.show()
plt.plot(data[1][["time"]], data[1][["gain"]])
plt.xscale("log")
plt.grid(True)
