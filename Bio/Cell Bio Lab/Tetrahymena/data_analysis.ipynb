# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
beads = [7,9,9,5,8,12,4,3,10,8,7,6,17,5,7,15,11,13,7,9]
counts, bins = np.histogram(beads, bins=7)
plt.hist(bins[:-1], bins, weights=counts, rwidth=.9, align='left')
plt.savefig('fig.png')
